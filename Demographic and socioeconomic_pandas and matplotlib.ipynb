# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv('/Users/MacBook/Desktop/sample_csv/demo.csv')

# %%
df.head(200)
# Out:
#            DEMO_IND                                 Indicator LOCATION  \
# 0    SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 1    SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 2    SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 3    SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 4    SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# ..              ...                                       ...      ...
# 195  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      CZE
# 196  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      CZE
# 197  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      CZE
# 198  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      CZE
# 199  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      CZE
#
#        Country  TIME  Time  Value Flag Codes Flags
# 0    Australia  1970  1970  2.859        NaN   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270038 entries, 0 to 270037
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   DEMO_IND    270038 non-null  object
#  1   Indicator   270038 non-null  object
#  2   LOCATION    270038 non-null  object
#  3   Country     270038 non-null  object
#  4   TIME        270038 non-null  int64
#  5   Time        270038 non-null  int64
#  6   Value       267972 non-null  float64
#  7   Flag Codes  2066 non-null    object
#  8   Flags       2066 non-null    object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 18.5+ MB

# %%
df.head()
# Out:
#          DEMO_IND                                 Indicator LOCATION  \
# 0  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 1  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 2  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 3  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 4  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
#
#      Country  TIME  Time  Value Flag Codes Flags
# 0  Australia  1970  1970  2.859        NaN   NaN
# 1  Australia  1971  1971  2.961        NaN   NaN
# 2  Australia  1972  1972  2.744        NaN   NaN
# 3  Australia  1973  1973  2.491        NaN   NaN
# 4  Australia  1974  1974  2.397        NaN   NaN

# %%
df.columns
# Out:
# Index(['DEMO_IND', 'Indicator', 'LOCATION', 'Country', 'TIME', 'Time', 'Value',
#        'Flag Codes', 'Flags'],
#       dtype='object')

# %%
df.rename(columns={'DEMO_IND':'ID & DEMO_IND'}, inplace=True)

# %%
df.head()
# Out:
#     ID & DEMO_IND                                 Indicator LOCATION  \
# 0  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 1  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 2  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 3  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 4  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
#
#      Country  TIME  Time  Value Flag Codes Flags
# 0  Australia  1970  1970  2.859        NaN   NaN
# 1  Australia  1971  1971  2.961        NaN   NaN
# 2  Australia  1972  1972  2.744        NaN   NaN
# 3  Australia  1973  1973  2.491        NaN   NaN
# 4  Australia  1974  1974  2.397        NaN   NaN

# %%
locdata = df['Country']

# %%
locdata.nunique()
# Out:
# 233

# %%
locdata.unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Czechia', 'Denmark',
#        'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland',
#        'Ireland', 'Italy', 'Japan', 'Republic of Korea', 'Luxembourg',
#        'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Poland',
#        'Portugal', 'Slovakia', 'Afghanistan', 'Albania', 'Algeria',
#        'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia',
#        'Aruba', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Cabo Verde',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Costa Rica', "Côte d'Ivoire", 'Croatia',
#        'Cuba', 'Cyprus', "Democratic People's Republic of Korea",
# ...

# %%
percentloc = locdata.value_counts()

# %%
percentloc.head(10)
# Out:
# Costa Rica            1481
# Honduras              1472
# Colombia              1471
# El Salvador           1468
# Indonesia             1466
# Thailand              1462
# Madagascar            1462
# Ghana                 1461
# Dominican Republic    1459
# Mexico                1459
# Name: Country, dtype: int64

# %%
percentloc = locdata.value_counts(normalize=True)
percentloc.head(10)
# Out:
# Costa Rica            0.005484
# Honduras              0.005451
# Colombia              0.005447
# El Salvador           0.005436
# Indonesia             0.005429
# Thailand              0.005414
# Madagascar            0.005414
# Ghana                 0.005410
# Dominican Republic    0.005403
# Mexico                0.005403
# Name: Country, dtype: float64

# %%
df.columns
# Out:
# Index(['ID & DEMO_IND', 'Indicator', 'LOCATION', 'Country', 'TIME', 'Time',
#        'Value', 'Flag Codes', 'Flags'],
#       dtype='object')

# %%
df[(df['TIME'] >= 1999)]
# Out:
#          ID & DEMO_IND                                 Indicator LOCATION  \
# 29      SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 30      SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 31      SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 32      SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 33      SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# ...                ...                                       ...      ...
# 270033          200101                         Total population       MAF
# 270034          200101                         Total population       MAF
# 270035          200101                         Total population       MAF
# 270036          200101                         Total population       MAF
# 270037          200101                         Total population       MAF
#
#                            Country  TIME  Time   Value Flag Codes Flags
# ...

# %%
TIME1999 = df[(df['TIME'] >= 1999)]

# %%
TIME1999.head()
# Out:
#      ID & DEMO_IND                                 Indicator LOCATION  \
# 29  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 30  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 31  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 32  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 33  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
#
#       Country  TIME  Time  Value Flag Codes Flags
# 29  Australia  1999  1999  1.755        NaN   NaN
# 30  Australia  2000  2000  1.756        NaN   NaN
# 31  Australia  2001  2001  1.739        NaN   NaN
# 32  Australia  2002  2002  1.756        NaN   NaN
# 33  Australia  2003  2003  1.748        NaN   NaN

# %%
df[(df['LOCATION'].str.contains('JPN'))].head()
# Out:
#       ID & DEMO_IND                                 Indicator LOCATION  \
# 672  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      JPN
# 673  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      JPN
# 674  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      JPN
# 675  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      JPN
# 676  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      JPN
#
#     Country  TIME  Time  Value Flag Codes Flags
# 672   Japan  1970  1970  2.135        NaN   NaN
# 673   Japan  1971  1971  2.160        NaN   NaN
# 674   Japan  1972  1972  2.140        NaN   NaN
# 675   Japan  1973  1973  2.140        NaN   NaN
# 676   Japan  1974  1974  2.050        NaN   NaN

# %%
df.shape
# Out:
# (270038, 9)

# %%
df.sample()
# Out:
#        ID & DEMO_IND                     Indicator LOCATION Country  TIME  \
# 144501        200144  Population aged 15-24 years       SRB  Serbia  1976
#
#         Time     Value Flag Codes Flags
# 144501  1976  1447.491        NaN   NaN

# %%
df.index
# Out:
# RangeIndex(start=0, stop=270038, step=1)

# %%
df[111178:111199]
# Out:
#        ID & DEMO_IND                     Indicator LOCATION  Country  TIME  \
# 111178        200144  Population aged 15-24 years       MAR  Morocco  2009
# 111179        200144  Population aged 15-24 years       MAR  Morocco  2010
# 111180        200144  Population aged 15-24 years       MAR  Morocco  2011
# 111181        200144  Population aged 15-24 years       MAR  Morocco  2012
# 111182        200144  Population aged 15-24 years       MAR  Morocco  2013
# 111183        200144  Population aged 15-24 years       MAR  Morocco  2014
# 111184        200144  Population aged 15-24 years       MAR  Morocco  2015
# 111185        200144  Population aged 15-24 years       MAR  Morocco  2016
# 111186        200144  Population aged 15-24 years       MAR  Morocco  2017
# 111187        200144  Population aged 15-24 years       MAR  Morocco  2018
# 111188        200144  Population aged 15-24 years       MAR  Morocco  2019
# ...

# %%
df.iloc[98374:98390]
# Out:
#            ID & DEMO_IND                                      Indicator  \
# 98374  NY_GNP_PCAP_PP_CD  GNI per capita, PPP (current international $)
# 98375  NY_GNP_PCAP_PP_CD  GNI per capita, PPP (current international $)
# 98376  NY_GNP_PCAP_PP_CD  GNI per capita, PPP (current international $)
# 98377  NY_GNP_PCAP_PP_CD  GNI per capita, PPP (current international $)
# 98378  NY_GNP_PCAP_PP_CD  GNI per capita, PPP (current international $)
# 98379  NY_GNP_PCAP_PP_CD  GNI per capita, PPP (current international $)
# 98380  NY_GNP_PCAP_PP_CD  GNI per capita, PPP (current international $)
# 98381  NY_GNP_PCAP_PP_CD  GNI per capita, PPP (current international $)
# 98382  NY_GNP_PCAP_PP_CD  GNI per capita, PPP (current international $)
# 98383  NY_GNP_PCAP_PP_CD  GNI per capita, PPP (current international $)
# 98384  NY_GNP_PCAP_PP_CD  GNI per capita, PPP (current international $)
# 98385  NY_GNP_PCAP_PP_CD  GNI per capita, PPP (current international $)
# ...

# %%
df.iloc[0:5]
# Out:
#     ID & DEMO_IND                                 Indicator LOCATION  \
# 0  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 1  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 2  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 3  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 4  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
#
#      Country  TIME  Time  Value Flag Codes Flags
# 0  Australia  1970  1970  2.859        NaN   NaN
# 1  Australia  1971  1971  2.961        NaN   NaN
# 2  Australia  1972  1972  2.744        NaN   NaN
# 3  Australia  1973  1973  2.491        NaN   NaN
# 4  Australia  1974  1974  2.397        NaN   NaN

# %%
df_cleaned = df.dropna()
df_cleaned.shape
# Out:
# (0, 9)

# %%
df_without_type = df.dropna(axis =1)
df_without_type.shape
# Out:
# (270038, 6)

# %%
df = df.drop(['Flags'], axis=1)
df.head()
# Out:
#     ID & DEMO_IND                                 Indicator LOCATION  \
# 0  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 1  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 2  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 3  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 4  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
#
#      Country  TIME  Time  Value Flag Codes
# 0  Australia  1970  1970  2.859        NaN
# 1  Australia  1971  1971  2.961        NaN
# 2  Australia  1972  1972  2.744        NaN
# 3  Australia  1973  1973  2.491        NaN
# 4  Australia  1974  1974  2.397        NaN

# %%
df = df.drop(['Flag Codes'], axis=1)
df.head()
# Out:
#     ID & DEMO_IND                                 Indicator LOCATION  \
# 0  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 1  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 2  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 3  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 4  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
#
#      Country  TIME  Time  Value
# 0  Australia  1970  1970  2.859
# 1  Australia  1971  1971  2.961
# 2  Australia  1972  1972  2.744
# 3  Australia  1973  1973  2.491
# 4  Australia  1974  1974  2.397

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270038 entries, 0 to 270037
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ID & DEMO_IND  270038 non-null  object
#  1   Indicator      270038 non-null  object
#  2   LOCATION       270038 non-null  object
#  3   Country        270038 non-null  object
#  4   TIME           270038 non-null  int64
#  5   Time           270038 non-null  int64
#  6   Value          267972 non-null  float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 14.4+ MB

# %%
df.head()
# Out:
#     ID & DEMO_IND                                 Indicator LOCATION  \
# 0  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 1  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 2  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 3  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
# 4  SP_DYN_TFRT_IN  Fertility rate, total (births per woman)      AUS
#
#      Country  TIME  Time  Value
# 0  Australia  1970  1970  2.859
# 1  Australia  1971  1971  2.961
# 2  Australia  1972  1972  2.744
# 3  Australia  1973  1973  2.491
# 4  Australia  1974  1974  2.397
